# %%
# %%bash
#
# echo $SHELL # I'm using /bin/zsh
#
# pwd
# ls -lh ~
#
# # the second one is absolute, because it starts with users.
# Out:
# /bin/zsh
# /Users/joannajiayiyao/Desktop/datdasci350/datasci350
# total 7192
# drwxr-xr-x    3 joannajiayiyao  staff    96B Aug  4 09:35 Applications
# drwx------@  48 joannajiayiyao  staff   1.5K Sep 22 17:51 Desktop
# drwx------@   8 joannajiayiyao  staff   256B Sep 22 17:45 Documents
# drwx------+ 230 joannajiayiyao  staff   7.2K Sep 22 17:15 Downloads
# drwx------@  94 joannajiayiyao  staff   2.9K Sep  8 21:02 Library
# drwx------    6 joannajiayiyao  staff   192B Apr 24 17:20 Movies
# drwx------+   4 joannajiayiyao  staff   128B Mar 30 18:37 Music
# drwx------+   6 joannajiayiyao  staff   192B May 21 13:57 Pictures
# drwxr-xr-x+   4 joannajiayiyao  staff   128B Mar 11  2026 Public
# drwxr-xr-x@   9 joannajiayiyao  staff   288B Sep 22 15:51 Zotero
# -rw-r--r--@   1 joannajiayiyao  staff   1.7M Sep 18 14:27 ciliatedAC_v_nonciliatedAC.csv
# -rw-r--r--@   1 joannajiayiyao  staff   1.8M Sep 18 14:31 ciliatedAC_v_nonciliatedAC_df.csv
# ...

# %%
# %%bash
#
# mkdir -p project/{data,scripts,docs}
# touch project/data/{01..05}.csv
#
# touch project/scripts/clean.py
# touch project/scripts/analyse.py
# touch project/scripts/plot.py
#
# mkdir -p project/backup && cp project/scripts/*.py project/backup
#
# touch project/docs/countries.txt
# echo "brazil" > project/docs/countries.txt
# echo "india" >> project/docs/countries.txt
#
# grep -n "in" project/docs/countries.txt
#
# cat project/docs/countries.txt
# Out:
# 2:india
# brazil
# india
